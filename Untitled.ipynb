# %%
import pandas as pd

# %%
playlist_tracks = pd.read_csv("Dataset/playlist_tracks_df.csv")
artist_details = pd.read_csv("Dataset/artist_details_df.csv")
audio_features = pd.read_csv("Dataset/audio_features_df.csv")
related_artists = pd.read_csv("Dataset/related_artists_df.csv")

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ### Cleaning playlist_tracks

# %%
playlist_tracks.head()
# Out:
#    Unnamed: 0                      Track Name                Track ID  \
# 0           0                 Kahani Suno 2.0  4VsP4Dm8gsibRxB5I2hEkw
# 1           1                    Apna Bana Le  1zhpW0PLYAhzF3X49GaAOX
# 2           2                  Maan Meri Jaan  1418IuVKQPTYqt7QNJ9RXN
# 3           3               Jhoome Jo Pathaan  6FAYpZ4jve8vpvTwUvjK6H
# 4           4  Besharam Rang (From "Pathaan")  0CtZpaOhtzvLV3FfcsVpQo
#
#                                         Artist Names  \
# 0                                   ['Kaifi Khalil']
# 1  ['Sachin-Jigar', 'Arijit Singh', 'Amitabh Bhat...
# 2                                           ['King']
# 3  ['Vishal-Shekhar', 'Arijit Singh', 'Sukriti Ka...
# 4  ['Vishal-Shekhar', 'Shilpa Rao', 'Caralisa Mon...
#
#                                           Artist IDs  Track Popularity  \
# 0                         ['1n9EM0Y4A89vuRiA93gSS9']                81
# 1  ['1mBydYMVBECdDmMfE2sEUO', '4YRxDV8wJFPHPTeXep...                76
# 2                         ['5NHm4TU5Twz7owibYxJfFU']                85
# 3  ['6Mv8GjQa7LKUGCAqa9qqdb', '4YRxDV8wJFPHPTeXep...                82
# 4  ['6Mv8GjQa7LKUGCAqa9qqdb', '19LIHDDSHBD5NyYHI3...                82
#
#   Date Released            Date Added
# 0    2022-05-31  2023-03-01T10:20:49Z
# 1    2022-12-06  2023-03-01T10:20:49Z
# 2    2022-10-12  2023-03-01T10:20:49Z
# 3    2022-12-22  2023-03-01T10:20:49Z
# 4    2022-12-12  2023-03-01T10:20:49Z

# %%
playlist_tracks.columns
# Out:
# Index(['Unnamed: 0', 'Track Name', 'Track ID', 'Artist Names', 'Artist IDs',
#        'Track Popularity', 'Date Released', 'Date Added'],
#       dtype='object')

# %%
playlist_tracks["Track Rank"] = playlist_tracks["Unnamed: 0"]+1

# %%
playlist_tracks.tail()
# Out:
#     Unnamed: 0                    Track Name                Track ID  \
# 45          45  Maiyya Mainu (From "Jersey")  4PwTeFfKqmR3XIeXXUBDOf
# 46          46                Basti Ka Hasti  3k9PtGmPNnQtt32TKWm6f3
# 47          47                     We Rollin  6ZYxNjuAU9Vy3VtF6W1dtE
# 48          48           Under The Influence  5IgjP7X4th6nMNDh4akUHb
# 49          49    Ranjithame (From "Varisu")  1LbBOhicFmu7ktJqIHCELt
#
#                                       Artist Names  \
# 45           ['Sachet-Parampara', 'Sachet Tandon']
# 46                                     ['MC STAN']
# 47                                       ['Shubh']
# 48                                 ['Chris Brown']
# 49  ['Thalapathy Vijay', 'M.M.Manasi', 'Thaman S']
#
#                                            Artist IDs  Track Popularity  \
# 45  ['1SyKki7JI1AZNKwgNMkn25', '6WOdPJmexxFINcKMkP...                75
# 46                         ['5uemEEtB1ZC3s1KM7gReeH']                73
# 47                         ['5r3wPya2PpeTTsXsGhQU8O']                75
# 48                         ['7bXgB6jMjp9ATFy66eO08Z']                88
# 49  ['0fhunuOz2OuOEr3YK5ctSm', '3JGrxsZ6kfzJrfwsxw...                76
#
#    Date Released            Date Added  Track Rank
# 45    2021-12-08  2023-03-01T10:20:49Z          46
# 46    2022-02-18  2023-03-01T10:20:49Z          47
# 47    2021-09-09  2023-03-01T10:20:49Z          48
# 48    2019-10-04  2023-03-01T10:20:49Z          49
# 49    2022-11-05  2023-03-01T10:20:49Z          50

# %%
playlist_tracks.drop('Unnamed: 0', inplace=True, axis = "columns")

# %%
playlist_tracks['Date Added'] = pd.to_datetime(playlist_tracks['Date Added'])
playlist_tracks['Date Released'] = pd.to_datetime(playlist_tracks['Date Released'])

# %%
playlist_tracks["Date Added"] = playlist_tracks["Date Added"].dt.date

# %%
playlist_tracks['Date Added'] = pd.to_datetime(playlist_tracks['Date Added'])

# %%
playlist_tracks.head()
# Out:
#                        Track Name                Track ID  \
# 0                 Kahani Suno 2.0  4VsP4Dm8gsibRxB5I2hEkw
# 1                    Apna Bana Le  1zhpW0PLYAhzF3X49GaAOX
# 2                  Maan Meri Jaan  1418IuVKQPTYqt7QNJ9RXN
# 3               Jhoome Jo Pathaan  6FAYpZ4jve8vpvTwUvjK6H
# 4  Besharam Rang (From "Pathaan")  0CtZpaOhtzvLV3FfcsVpQo
#
#                                         Artist Names  \
# 0                                   ['Kaifi Khalil']
# 1  ['Sachin-Jigar', 'Arijit Singh', 'Amitabh Bhat...
# 2                                           ['King']
# 3  ['Vishal-Shekhar', 'Arijit Singh', 'Sukriti Ka...
# 4  ['Vishal-Shekhar', 'Shilpa Rao', 'Caralisa Mon...
#
#                                           Artist IDs  Track Popularity  \
# 0                         ['1n9EM0Y4A89vuRiA93gSS9']                81
# 1  ['1mBydYMVBECdDmMfE2sEUO', '4YRxDV8wJFPHPTeXep...                76
# 2                         ['5NHm4TU5Twz7owibYxJfFU']                85
# 3  ['6Mv8GjQa7LKUGCAqa9qqdb', '4YRxDV8wJFPHPTeXep...                82
# 4  ['6Mv8GjQa7LKUGCAqa9qqdb', '19LIHDDSHBD5NyYHI3...                82
#
#   Date Released Date Added  Track Rank
# 0    2022-05-31 2023-03-01           1
# 1    2022-12-06 2023-03-01           2
# 2    2022-10-12 2023-03-01           3
# 3    2022-12-22 2023-03-01           4
# 4    2022-12-12 2023-03-01           5

# %%
# Exploding Artist Names and Artist ID columns

import ast

# convert string columns to lists
playlist_tracks['Artist Names'] = playlist_tracks['Artist Names'].apply(ast.literal_eval)
playlist_tracks['Artist IDs'] = playlist_tracks['Artist IDs'].apply(ast.literal_eval)

# explode the 'Artist Names' column
playlist_tracks = playlist_tracks.explode('Artist Names')

# explode the 'Artist IDs' column
playlist_tracks = playlist_tracks.explode('Artist IDs')

# %%
playlist_tracks.rename(columns={'Track Name': 'track_name', 'Track ID': 'track_id', 'Artist Names': 'artist_name',  'Artist IDs': 'artist_id','Track Popularity': 'track_popularity', 'Date Released': 'date_released', 'Track Rank': 'track_rank'}, inplace=True)

# %%
playlist_tracks.rename(columns={'Date Added': 'date_added'}, inplace=True)

# %%
playlist_tracks
# Out:
#                     track_name                track_id   artist_name  \
# 0              Kahani Suno 2.0  4VsP4Dm8gsibRxB5I2hEkw  Kaifi Khalil
# 1                 Apna Bana Le  1zhpW0PLYAhzF3X49GaAOX  Sachin-Jigar
# 1                 Apna Bana Le  1zhpW0PLYAhzF3X49GaAOX  Sachin-Jigar
# 1                 Apna Bana Le  1zhpW0PLYAhzF3X49GaAOX  Sachin-Jigar
# 1                 Apna Bana Le  1zhpW0PLYAhzF3X49GaAOX  Arijit Singh
# ..                         ...                     ...           ...
# 49  Ranjithame (From "Varisu")  1LbBOhicFmu7ktJqIHCELt    M.M.Manasi
# 49  Ranjithame (From "Varisu")  1LbBOhicFmu7ktJqIHCELt    M.M.Manasi
# 49  Ranjithame (From "Varisu")  1LbBOhicFmu7ktJqIHCELt      Thaman S
# 49  Ranjithame (From "Varisu")  1LbBOhicFmu7ktJqIHCELt      Thaman S
# 49  Ranjithame (From "Varisu")  1LbBOhicFmu7ktJqIHCELt      Thaman S
#
#                  artist_id  track_popularity date_released date_added  \
# 0   1n9EM0Y4A89vuRiA93gSS9                81    2022-05-31 2023-03-01
# 1   1mBydYMVBECdDmMfE2sEUO                76    2022-12-06 2023-03-01
# 1   4YRxDV8wJFPHPTeXepOstw                76    2022-12-06 2023-03-01
# 1   2fMqTqiTxUDlmcOEPaQSsx                76    2022-12-06 2023-03-01
# 1   1mBydYMVBECdDmMfE2sEUO                76    2022-12-06 2023-03-01
# ..                     ...               ...           ...        ...
# 49  3JGrxsZ6kfzJrfwsxwERhS                76    2022-11-05 2023-03-01
# 49  2FgHPfRprDaylrSRVf1UlN                76    2022-11-05 2023-03-01
# 49  0fhunuOz2OuOEr3YK5ctSm                76    2022-11-05 2023-03-01
# 49  3JGrxsZ6kfzJrfwsxwERhS                76    2022-11-05 2023-03-01
# 49  2FgHPfRprDaylrSRVf1UlN                76    2022-11-05 2023-03-01
#
#     track_rank
# 0            1
# 1            2
# 1            2
# 1            2
# 1            2
# ..         ...
# 49          50
# 49          50
# 49          50
# 49          50
# 49          50
#
# [333 rows x 8 columns]

# %%
playlist_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track Name        333 non-null    object
#  1   Track ID          333 non-null    object
#  2   Artist Names      333 non-null    object
#  3   Artist IDs        333 non-null    object
#  4   Track Popularity  333 non-null    int64
#  5   Date Released     333 non-null    datetime64[ns]
#  6   Date Added        333 non-null    datetime64[ns]
#  7   Track Rank        333 non-null    int64
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 23.4+ KB

# %% [markdown]
# ### Cleaning artist_details

# %%
artist_details.head()
# Out:
#    Unnamed: 0               Artist ID   Artist Name  Num Followers  \
# 0           0  3lmszXxkp47K9kDCRRPU8p  Laddi Chahal          24504
# 1           1  6nAMu7pGqdwUSsGMZPUvSk           40k            751
# 2           2  1rdQOMFFtoskDXXUVjiGo9  Shweta Mohan         750829
# 3           3  3gBKY0y3dFFVRqicLnVZYz   Alka Yagnik        8427469
# 4           4  1i31OYo0s5VoMCaMRJFZkJ      The Paul            354
#
#                                               Genres  Popularity
# 0                        ['desi pop', 'punjabi pop']          62
# 1                                                 []          60
# 2                             ['filmi', 'tamil pop']          71
# 3  ['classic bollywood', 'desi pop', 'filmi', 'ha...          81
# 4                                                 []          60

# %%
artist_details.drop('Unnamed: 0', inplace=True, axis = "columns")

# %%
artist_details.rename(columns={'Num Followers': 'num_followers', 'Artist Name': 'artist_name',  'Artist ID': 'artist_id','Genres': 'genres',  'Popularity': 'popularity'}, inplace=True)

# %%
artist_details.head()
# Out:
#                 artist_id   artist_name  num_followers  \
# 0  3lmszXxkp47K9kDCRRPU8p  Laddi Chahal          24504
# 1  6nAMu7pGqdwUSsGMZPUvSk           40k            751
# 2  1rdQOMFFtoskDXXUVjiGo9  Shweta Mohan         750829
# 3  3gBKY0y3dFFVRqicLnVZYz   Alka Yagnik        8427469
# 4  1i31OYo0s5VoMCaMRJFZkJ      The Paul            354
#
#                                               genres  popularity
# 0                        ['desi pop', 'punjabi pop']          62
# 1                                                 []          60
# 2                             ['filmi', 'tamil pop']          71
# 3  ['classic bollywood', 'desi pop', 'filmi', 'ha...          81
# 4                                                 []          60

# %% [markdown]
# ### Cleaning audio_features

# %%
audio_features.head()
# Out:
#                  track_id                                       analysis_url  \
# 0  4VsP4Dm8gsibRxB5I2hEkw  https://api.spotify.com/v1/audio-analysis/4VsP...
# 1  1zhpW0PLYAhzF3X49GaAOX  https://api.spotify.com/v1/audio-analysis/1zhp...
# 2  1418IuVKQPTYqt7QNJ9RXN  https://api.spotify.com/v1/audio-analysis/1418...
# 3  6FAYpZ4jve8vpvTwUvjK6H  https://api.spotify.com/v1/audio-analysis/6FAY...
# 4  0CtZpaOhtzvLV3FfcsVpQo  https://api.spotify.com/v1/audio-analysis/0CtZ...
#
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.9090         0.577       173638   0.379          0.000586   11
# 1        0.8030         0.586       261702   0.562          0.000006    9
# 2        0.3540         0.698       194654   0.505          0.000000    6
# 3        0.0964         0.817       208164   0.738          0.000000    7
# 4        0.0587         0.773       258474   0.795          0.002370    8
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence
# 0    0.0986   -13.235     1       0.0374  139.585               3    0.260
# 1    0.0630    -7.399     1       0.0267   93.982               4    0.436
# 2    0.0995    -8.242     0       0.0356   95.868               4    0.396
# 3    0.3310    -7.639     1       0.0748  104.964               4    0.616
# 4    0.1540    -5.537     0       0.0412  115.997               4    0.649

# %%
audio_features.drop('Unnamed: 0', inplace=True, axis = "columns")

# %% [markdown]
# ### Cleaning related_artists

# %%
related_artists.head()
# Out:
#                 Artist ID       Related Artist ID Related Artist Name
# 0  3lmszXxkp47K9kDCRRPU8p  2hmIpieYhZEQJDzlWpNMQg          Romey Maan
# 1  3lmszXxkp47K9kDCRRPU8p  3OQRPFFS3OsltFjFAXu1kE       Parmish Verma
# 2  3lmszXxkp47K9kDCRRPU8p  4j4SDkxwy0Z68dIh5Vr7fh       Bhindder Burj
# 3  3lmszXxkp47K9kDCRRPU8p  28kGdf2ant8i73Fab2F7xq      Amantej Hundal
# 4  3lmszXxkp47K9kDCRRPU8p  5wGjQPYmBAnDmtNeOMoavY         Tyson Sidhu

# %%
related_artists.drop('Unnamed: 0', inplace=True, axis = "columns")

# %%
related_artists.rename(columns={'Artist ID': 'artist_id','Related Artist ID': 'related_artist_id',  'Related Artist Name': 'related_artist_name'}, inplace=True)

# %%
related_artists.head()
# Out:
#                 artist_id       related_artist_id related_artist_name
# 0  3lmszXxkp47K9kDCRRPU8p  2hmIpieYhZEQJDzlWpNMQg          Romey Maan
# 1  3lmszXxkp47K9kDCRRPU8p  3OQRPFFS3OsltFjFAXu1kE       Parmish Verma
# 2  3lmszXxkp47K9kDCRRPU8p  4j4SDkxwy0Z68dIh5Vr7fh       Bhindder Burj
# 3  3lmszXxkp47K9kDCRRPU8p  28kGdf2ant8i73Fab2F7xq      Amantej Hundal
# 4  3lmszXxkp47K9kDCRRPU8p  5wGjQPYmBAnDmtNeOMoavY         Tyson Sidhu

# %% [markdown]
# # Uploading to Database

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:ankursingh28@localhost:3306/spotify")

# %%
playlist_tracks.to_sql(
    name = "playlist_tracks",
    con = engine,
    index = False,
    if_exists = 'replace')
# Out:
# 333

# %%
artist_details.to_sql(
    name = "artist_details",
    con = engine,
    index = False,
    if_exists = 'replace')
# Out:
# 82

# %%
audio_features.to_sql(
    name = "audio_features",
    con = engine,
    index = False,
    if_exists = 'replace')
# Out:
# 50

# %%
related_artists.to_sql(
    name = "related_artists",
    con = engine,
    index = False,
    if_exists = 'replace')
# Out:
# 1496
